# %% [markdown]
# <a href="https://colab.research.google.com/github/seeuni0320/AI-ML/blob/main/Week9_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
export_graphviz(tree_clf, out_file="iris_tree.dot", feature_names=["꽃잎 길이(cm)", "꽃잎 너비 (cm)"], class_names=iris.target_names, rounded=True, filled=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4267/1433322412.py in <cell line: 0>()
# ----> 1 export_graphviz(tree_clf, out_file="iris_tree.dot", feature_names=["꽃잎 길이(cm)", "꽃잎 너비 (cm)"], class_names=iris.target_names, rounded=True, filled=True)
#
# NameError: name 'tree_clf' is not defined

# %%
custom_camp = ListedColormap(['#fafabo', '#9898ff', '#a0faa0'])
plt.figure(figsize=(8, 4))

lengths, widths = np.meshgrid(np.linspace(0, 7.2, 100), np.linspace(0, 3, 100))
x_iris_all = np.c_[lengths.ravel(), widths.ravel()]
y_pred = tree_clf.predict(x_iris_all) .reshape(lengths.shape)

plt.contourf(lengths, widths, y_pred, alpha=0.3, cmap=custom_camp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4267/2637498677.py in <cell line: 0>()
#       4 lengths, widths = np.meshgrid(np.linspace(0, 7.2, 100), np.linspace(0, 3, 100))
#       5 x_iris_all = np.c_[lengths.ravel(), widths.ravel()]
# ----> 6 y_pred = tree_clf.predict(x_iris_all) .reshape(lengths.shape)
#       7
#       8 plt.contourf(lengths, widths, y_pred, alpha=0.3, cmap=custom_camp)
#
# NameError: name 'tree_clf' is not defined

# %%
for idx, (names, style) in enumerate(zip(iris.target_names, ("yo", "bs", "g^"))):
    plt.plot(x_iris[:,0][y_iris == idx], x_iris[:,1], [y_iris ==idx], style, label=f"Iris {name}")

# %%
tree_clf_deeper = DecisionnTreeClassifier(max_depth=3, random_state == 42)
tree_clf_deeper.fit(x_iris, y_iris)
th0, th1, th2a, th2b = tree_clf_deeper.tree_.threshold[[0, 1, 2, 3, 6]]
plt.xlabel("Petal length (cm)")
plt.ylabel("Petal width (cm)")
plt.plot([th0, th0], [0,3], "k--", linewidth=2)
plt.plot([th0, 7.2], [th1, th1], "k--", linewidth=2)
plt.plot([th2a, th2a], [0, th1], "k--", linewidth=2)
plt.plot([th2b, th2b], [th1, 3], "k--", linewidth=2)
plt.text(th0-0.05, 1.0, "Depth=0", horizontalalignment="right", fontsize=15)
plt.text(3.2, th1+ 0.02, "Depth=1", horizontalalignment="botto", fontsize=13)
plt.text(th2a + 0.05, 0.5, "(Depth=2)", fontsize=11)
pli.axis([0, 7.2, 0, 3])
plt.legend()

plt.show()
